# %% [markdown]
# # The Sentinel Ego — Full Pipeline Notebook
# **IEEE TIFS Submission | All 5 Phases in Sequence**
#
# This notebook runs all five phases of the Sentinel Ego framework end-to-end.
# For individual phase details, see the dedicated notebooks in this folder.
#
# ## Execution Order
# 1. Phase 1: PBI — Enron mining, archetype discovery, Markov chain synthesis
# 2. Phase 2: AIF — 42-feature adversarial interaction profiling
# 3. Phase 3: FAL — Federated learning with differential privacy (FedAvg, RDP)
# 4. Phase 4: CDE — Collective deception evolution (15 rounds, 3 strategies)
# 5. Phase 5: Mirror Defense — Adaptive recovery + ablation + cross-validation

# %%
# Install dependencies
# !pip install -q pandas numpy scipy scikit-learn lightgbm xgboost tqdm matplotlib seaborn python-dateutil pyyaml

# %%
# Run Phase 1
# %run notebooks/Phase1_PBI_Enron_Mining.ipynb

# %%
# Run Phase 2
# %run notebooks/Phase2_AIF_Profiler.ipynb

# %%
# Run Phase 3
# %run notebooks/Phase3_FAL_FedAvg_DP.ipynb

# %%
# Run Phase 4
# %run notebooks/phase4_collective_deception_evolution.ipynb

# %%
# Run Phase 5
# %run notebooks/phase5_mirror_defense_evaluation.ipynb

# %% [markdown]
# ## Final Results Summary

# %%
import pandas as pd
print('=== PHASE 2: AIF PROFILER ===')
print(pd.read_csv('results/phase2_aif_results.csv').to_string(index=False))
print()
print('=== PHASE 3: FEDERATION ROUNDS ===')
print(pd.read_csv('results/phase3_federation_rounds.csv').to_string(index=False))
print()
print('=== PHASE 3: DP GUARANTEE ===')
print(pd.read_csv('results/phase3_dp_guarantee.csv').to_string(index=False))
print()
print('=== PHASE 4: CDE EVOLUTION ===')
print(pd.read_csv('results/phase4_cde_evolution.csv').to_string(index=False))
print()
print('=== PHASE 5: ABLATION STUDY ===')
print(pd.read_csv('results/phase5_ablation.csv').to_string(index=False))
print()
print('=== PHASE 5: CROSS-VALIDATION ===')
print(pd.read_csv('results/phase5_cross_validation.csv').to_string(index=False))
